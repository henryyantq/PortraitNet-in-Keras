# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2 as cv
from keras.models import Model, load_model
from keras.utils import plot_model
from keras.optimizers import Adam
from keras import backend
from keras.layers import Input, Add, Activation, BatchNormalization, Conv2D,\
     DepthwiseConv2D, UpSampling2D, MaxPooling2D, Dropout

def binary_focal_loss(y_true, y_pred, gamma=2, alpha=0.25):
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    eps = backend.epsilon()
    pt_1 = backend.clip(pt_1, eps, 1. - eps)
    pt_0 = backend.clip(pt_0, eps, 1. - eps)
    return -(backend.mean(alpha * backend.pow(1. - pt_1, gamma) * backend.log(pt_1), axis=-1) \
        + backend.mean((1 - alpha) * backend.pow(pt_0, gamma) * backend.log(1. - pt_0), axis=-1))

def D_Block(input_layer, filts, isConcat=False, concat_layer=None):
    # Is the bottom block?
    if isConcat == True and concat_layer is not None:
        bl = Add()([input_layer, concat_layer])
    else:
        bl = input_layer
    # Left conv 1x1
    bl_left_route = Conv2D(filters=filts, kernel_size=1, strides=1, padding='same', data_format='channels_last')(bl)
    bl_left_route = BatchNormalization()(bl_left_route)
    # Right conv dw 3x3
    bl_right_route = DepthwiseConv2D(kernel_size=3, strides=1, padding='same', data_format='channels_last')(bl)
    bl_right_route = BatchNormalization()(bl_right_route)
    bl_right_route = Activation('relu')(bl_right_route)
    # Right conv 1x1
    bl_right_route = Conv2D(filters=filts, kernel_size=1, strides=1, padding='same', data_format='channels_last')(bl_right_route)
    bl_right_route = BatchNormalization()(bl_right_route)
    bl_right_route = Activation('relu')(bl_right_route)
    # Right conv dw 3x3
    bl_right_route = DepthwiseConv2D(kernel_size=3, strides=1, padding='same', data_format='channels_last')(bl_right_route)
    bl_right_route = BatchNormalization()(bl_right_route)
    bl_right_route = Activation('relu')(bl_right_route)
    # Right conv 1x1
    bl_right_route = Conv2D(filters=filts, kernel_size=1, strides=1, padding='same', data_format='channels_last')(bl_right_route)
    bl_right_route = BatchNormalization()(bl_right_route)
    # Final concatenation
    bl_concat = Add()([bl_left_route, bl_right_route])
    bl_concat = Activation('relu')(bl_concat)
    return bl_concat

def D_stage(input_layer, filts, isConcat=False, concat_layer=None):
    bl = D_Block(input_layer, filts, isConcat, concat_layer)
    bl = UpSampling2D()(bl)
    bl = Dropout(0.2)(bl)
    return bl

def E_stage(input_layer, filts):
    bl = Conv2D(filters=filts, kernel_size=1, strides=1, padding='same', data_format='channels_last')(input_layer)
    bl = BatchNormalization()(bl)
    bl = Activation('relu')(bl)
    bl = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(bl)
    return bl

# Data preprocess
print('\nRunning Data Preprocess...')
X_route = '/content/drive/MyDrive/Assign_3/EG1800/input/'
Y_route = '/content/drive/MyDrive/Assign_3/EG1800/mask/'
files = os.listdir(X_route)
dataCount = 0

# Actually available data
for file in files:
    dataCount += 1

dataSize = 128
X_chs = 3
X_data = np.empty((dataCount, dataSize, dataSize, X_chs), dtype=np.float16)
Y_mask = np.empty((dataCount, dataSize, dataSize), dtype=np.float16)
Y_boundary = np.empty((dataCount, dataSize, dataSize), dtype=np.float16)
count = 0

for i in range(0, 2632):
    img = X_route + '%05d' % (i + 1) + '.jpg'
    mask = Y_route + '%05d' % (i + 1) + '_mask.png'
    if not os.path.exists(img) or not os.path.exists(mask):
        continue
    imgMat = cv.imread(img)
    maskMat = cv.imread(mask)
    imgMat = cv.resize(imgMat, (dataSize, dataSize))
    maskMat = cv.resize(maskMat, (dataSize, dataSize))
    X_data[count] = imgMat
    Y_mask[count] = cv.cvtColor(maskMat, cv.COLOR_BGR2GRAY) / 255
    maskMat_bin = cv.cvtColor(maskMat, cv.COLOR_BGR2GRAY)
    canny = cv.Canny(maskMat_bin, 50, 255)
    Y_boundary[count] = canny / 255
    count += 1
    print('Complete for data index ', count)

Y_mask = tf.expand_dims(Y_mask, axis=-1)
Y_boundary = tf.expand_dims(Y_boundary, axis=-1)
split = int(dataCount * 0.8)
X_train, Y_mask_train, Y_boundary_train = X_data[:split], Y_mask[:split], Y_boundary[:split]
X_test, Y_mask_test, Y_boundary_test = X_data[split:], Y_mask[split:], Y_boundary[split:]
print('Preprocess complete.\nTraining start...')
# Data preprocess complete

main_input = Input((dataSize, dataSize, X_chs), name='main_input')
initlyr = Conv2D(filters=1, kernel_size=1, padding='same', data_format='channels_last')(main_input)

enclyr_1 = E_stage(initlyr, 16) # -> 64x64x16
enclyr_2 = E_stage(enclyr_1, 32) # -> 32x32x32
enclyr_3 = E_stage(enclyr_2, 64) # -> 16x16x64
enclyr_4 = E_stage(enclyr_3, 128) # -> 8x8x128
enclyr_5 = E_stage(enclyr_4, 256) # -> 4x4x256

declyr_1 = D_stage(enclyr_5, 128) # -> 8x8x128
declyr_2 = D_stage(declyr_1, 64, True, enclyr_4) # -> 16x16x64
declyr_3 = D_stage(declyr_2, 32, True, enclyr_3) # -> 32x32x32
declyr_4 = D_stage(declyr_3, 16, True, enclyr_2) # -> 64x64x16
declyr_5 = D_stage(declyr_4, 8, True, enclyr_1) # -> 128x128x8

mask = Conv2D(filters=1, kernel_size=1, use_bias=False, data_format='channels_last', activation='sigmoid')(declyr_5)
boundary = Conv2D(filters=1, kernel_size=1, use_bias=False, data_format='channels_last', activation='sigmoid')(declyr_5)

model = Model(main_input, [mask, boundary], name='PortraitNet')

plot_model(model, to_file='/content/drive/MyDrive/Assign_3/structure.png')

adam = Adam(learning_rate=1e-3)

model.compile(
    optimizer=adam,
    loss=['binary_crossentropy', binary_focal_loss],
    loss_weights=[1., 1.],
    metrics=[['accuracy'], ['accuracy']]    
)

history = model.fit(X_train, [Y_mask_train, Y_boundary_train], batch_size=32, epochs=50)
print(history.history.keys())

loss = model.evaluate(X_test, [Y_mask_test, Y_boundary_test])
print('Result: ', loss)

model.save('/content/drive/MyDrive/Assign_3/PortraitNet.h5')

plt.plot(history.history['conv2d_21_accuracy'])
plt.plot(history.history['conv2d_22_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Mask', 'Boundary'], loc='lower right')
plt.show()

plt.plot(history.history['conv2d_21_loss'])
plt.plot(history.history['conv2d_22_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Mask', 'Boundary'], loc='upper right')
plt.show()

# Last Result: loss: 0.3654 - conv2d_21_loss: 0.3553 - conv2d_22_loss: 0.0101 - conv2d_21_accuracy: 0.8972 - conv2d_22_accuracy: 0.9817
# Out:
# Running Data Preprocess...
# Complete for data index  1
# Complete for data index  2
# Complete for data index  3
# Complete for data index  4
# Complete for data index  5
# Complete for data index  6
# Complete for data index  7
# Complete for data index  8
# Complete for data index  9
# Complete for data index  10
# Complete for data index  11
# Complete for data index  12
# Complete for data index  13
# Complete for data index  14
# Complete for data index  15
# Complete for data index  16
# Complete for data index  17
# Complete for data index  18
# Complete for data index  19
# Complete for data index  20
# Complete for data index  21
# Complete for data index  22
# Complete for data index  23
# Complete for data index  24
# Complete for data index  25
# Complete for data index  26
# Complete for data index  27
# Complete for data index  28
# Complete for data index  29
# Complete for data index  30
# Complete for data index  31
# Complete for data index  32
# Complete for data index  33
# Complete for data index  34
# Complete for data index  35
# Complete for data index  36
# Complete for data index  37
# Complete for data index  38
# Complete for data index  39
# Complete for data index  40
# Complete for data index  41
# Complete for data index  42
# Complete for data index  43
# Complete for data index  44
# Complete for data index  45
# Complete for data index  46
# Complete for data index  47
# Complete for data index  48
# Complete for data index  49
# Complete for data index  50
# Complete for data index  51
# Complete for data index  52
# Complete for data index  53
# Complete for data index  54
# Complete for data index  55
# Complete for data index  56
# Complete for data index  57
# Complete for data index  58
# Complete for data index  59
# Complete for data index  60
# Complete for data index  61
# Complete for data index  62
# Complete for data index  63
# Complete for data index  64
# Complete for data index  65
# Complete for data index  66
# Complete for data index  67
# Complete for data index  68
# Complete for data index  69
# Complete for data index  70
# Complete for data index  71
# Complete for data index  72
# Complete for data index  73
# Complete for data index  74
# Complete for data index  75
# Complete for data index  76
# Complete for data index  77
# Complete for data index  78
# Complete for data index  79
# Complete for data index  80
# Complete for data index  81
# Complete for data index  82
# Complete for data index  83
# Complete for data index  84
# Complete for data index  85
# Complete for data index  86
# Complete for data index  87
# Complete for data index  88
# Complete for data index  89
# Complete for data index  90
# Complete for data index  91
# Complete for data index  92
# Complete for data index  93
# Complete for data index  94
# Complete for data index  95
# Complete for data index  96
# Complete for data index  97
# Complete for data index  98
# Complete for data index  99
# Complete for data index  100
# Complete for data index  101
# Complete for data index  102
# Complete for data index  103
# Complete for data index  104
# Complete for data index  105
# Complete for data index  106
# Complete for data index  107
# Complete for data index  108
# Complete for data index  109
# Complete for data index  110
# Complete for data index  111
# Complete for data index  112
# Complete for data index  113
# Complete for data index  114
# Complete for data index  115
# Complete for data index  116
# Complete for data index  117
# Complete for data index  118
# Complete for data index  119
# Complete for data index  120
# Complete for data index  121
# Complete for data index  122
# Complete for data index  123
# Complete for data index  124
# Complete for data index  125
# Complete for data index  126
# Complete for data index  127
# Complete for data index  128
# Complete for data index  129
# Complete for data index  130
# Complete for data index  131
# Complete for data index  132
# Complete for data index  133
# Complete for data index  134
# Complete for data index  135
# Complete for data index  136
# Complete for data index  137
# Complete for data index  138
# Complete for data index  139
# Complete for data index  140
# Complete for data index  141
# Complete for data index  142
# Complete for data index  143
# Complete for data index  144
# Complete for data index  145
# Complete for data index  146
# Complete for data index  147
# Complete for data index  148
# Complete for data index  149
# Complete for data index  150
# Complete for data index  151
# Complete for data index  152
# Complete for data index  153
# Complete for data index  154
# Complete for data index  155
# Complete for data index  156
# Complete for data index  157
# Complete for data index  158
# Complete for data index  159
# Complete for data index  160
# Complete for data index  161
# Complete for data index  162
# Complete for data index  163
# Complete for data index  164
# Complete for data index  165
# Complete for data index  166
# Complete for data index  167
# Complete for data index  168
# Complete for data index  169
# Complete for data index  170
# Complete for data index  171
# Complete for data index  172
# Complete for data index  173
# Complete for data index  174
# Complete for data index  175
# Complete for data index  176
# Complete for data index  177
# Complete for data index  178
# Complete for data index  179
# Complete for data index  180
# Complete for data index  181
# Complete for data index  182
# Complete for data index  183
# Complete for data index  184
# Complete for data index  185
# Complete for data index  186
# Complete for data index  187
# Complete for data index  188
# Complete for data index  189
# Complete for data index  190
# Complete for data index  191
# Complete for data index  192
# Complete for data index  193
# Complete for data index  194
# Complete for data index  195
# Complete for data index  196
# Complete for data index  197
# Complete for data index  198
# Complete for data index  199
# Complete for data index  200
# Complete for data index  201
# Complete for data index  202
# Complete for data index  203
# Complete for data index  204
# Complete for data index  205
# Complete for data index  206
# Complete for data index  207
# Complete for data index  208
# Complete for data index  209
# Complete for data index  210
# Complete for data index  211
# Complete for data index  212
# Complete for data index  213
# Complete for data index  214
# Complete for data index  215
# Complete for data index  216
# Complete for data index  217
# Complete for data index  218
# Complete for data index  219
# Complete for data index  220
# Complete for data index  221
# Complete for data index  222
# Complete for data index  223
# Complete for data index  224
# Complete for data index  225
# Complete for data index  226
# Complete for data index  227
# Complete for data index  228
# Complete for data index  229
# Complete for data index  230
# Complete for data index  231
# Complete for data index  232
# Complete for data index  233
# Complete for data index  234
# Complete for data index  235
# Complete for data index  236
# Complete for data index  237
# Complete for data index  238
# Complete for data index  239
# Complete for data index  240
# Complete for data index  241
# Complete for data index  242
# Complete for data index  243
# Complete for data index  244
# Complete for data index  245
# Complete for data index  246
# Complete for data index  247
# Complete for data index  248
# Complete for data index  249
# Complete for data index  250
# Complete for data index  251
# Complete for data index  252
# Complete for data index  253
# Complete for data index  254
# Complete for data index  255
# Complete for data index  256
# Complete for data index  257
# Complete for data index  258
# Complete for data index  259
# Complete for data index  260
# Complete for data index  261
# Complete for data index  262
# Complete for data index  263
# Complete for data index  264
# Complete for data index  265
# Complete for data index  266
# Complete for data index  267
# Complete for data index  268
# Complete for data index  269
# Complete for data index  270
# Complete for data index  271
# Complete for data index  272
# Complete for data index  273
# Complete for data index  274
# Complete for data index  275
# Complete for data index  276
# Complete for data index  277
# Complete for data index  278
# Complete for data index  279
# Complete for data index  280
# Complete for data index  281
# Complete for data index  282
# Complete for data index  283
# Complete for data index  284
# Complete for data index  285
# Complete for data index  286
# Complete for data index  287
# Complete for data index  288
# Complete for data index  289
# Complete for data index  290
# Complete for data index  291
# Complete for data index  292
# Complete for data index  293
# Complete for data index  294
# Complete for data index  295
# Complete for data index  296
# Complete for data index  297
# Complete for data index  298
# Complete for data index  299
# Complete for data index  300
# Complete for data index  301
# Complete for data index  302
# Complete for data index  303
# Complete for data index  304
# Complete for data index  305
# Complete for data index  306
# Complete for data index  307
# Complete for data index  308
# Complete for data index  309
# Complete for data index  310
# Complete for data index  311
# Complete for data index  312
# Complete for data index  313
# Complete for data index  314
# Complete for data index  315
# Complete for data index  316
# Complete for data index  317
# Complete for data index  318
# Complete for data index  319
# Complete for data index  320
# Complete for data index  321
# Complete for data index  322
# Complete for data index  323
# Complete for data index  324
# Complete for data index  325
# Complete for data index  326
# Complete for data index  327
# Complete for data index  328
# Complete for data index  329
# Complete for data index  330
# Complete for data index  331
# Complete for data index  332
# Complete for data index  333
# Complete for data index  334
# Complete for data index  335
# Complete for data index  336
# Complete for data index  337
# Complete for data index  338
# Complete for data index  339
# Complete for data index  340
# Complete for data index  341
# Complete for data index  342
# Complete for data index  343
# Complete for data index  344
# Complete for data index  345
# Complete for data index  346
# Complete for data index  347
# Complete for data index  348
# Complete for data index  349
# Complete for data index  350
# Complete for data index  351
# Complete for data index  352
# Complete for data index  353
# Complete for data index  354
# Complete for data index  355
# Complete for data index  356
# Complete for data index  357
# Complete for data index  358
# Complete for data index  359
# Complete for data index  360
# Complete for data index  361
# Complete for data index  362
# Complete for data index  363
# Complete for data index  364
# Complete for data index  365
# Complete for data index  366
# Complete for data index  367
# Complete for data index  368
# Complete for data index  369
# Complete for data index  370
# Complete for data index  371
# Complete for data index  372
# Complete for data index  373
# Complete for data index  374
# Complete for data index  375
# Complete for data index  376
# Complete for data index  377
# Complete for data index  378
# Complete for data index  379
# Complete for data index  380
# Complete for data index  381
# Complete for data index  382
# Complete for data index  383
# Complete for data index  384
# Complete for data index  385
# Complete for data index  386
# Complete for data index  387
# Complete for data index  388
# Complete for data index  389
# Complete for data index  390
# Complete for data index  391
# Complete for data index  392
# Complete for data index  393
# Complete for data index  394
# Complete for data index  395
# Complete for data index  396
# Complete for data index  397
# Complete for data index  398
# Complete for data index  399
# Complete for data index  400
# Complete for data index  401
# Complete for data index  402
# Complete for data index  403
# Complete for data index  404
# Complete for data index  405
# Complete for data index  406
# Complete for data index  407
# Complete for data index  408
# Complete for data index  409
# Complete for data index  410
# Complete for data index  411
# Complete for data index  412
# Complete for data index  413
# Complete for data index  414
# Complete for data index  415
# Complete for data index  416
# Complete for data index  417
# Complete for data index  418
# Complete for data index  419
# Complete for data index  420
# Complete for data index  421
# Complete for data index  422
# Complete for data index  423
# Complete for data index  424
# Complete for data index  425
# Complete for data index  426
# Complete for data index  427
# Complete for data index  428
# Complete for data index  429
# Complete for data index  430
# Complete for data index  431
# Complete for data index  432
# Complete for data index  433
# Complete for data index  434
# Complete for data index  435
# Complete for data index  436
# Complete for data index  437
# Complete for data index  438
# Complete for data index  439
# Complete for data index  440
# Complete for data index  441
# Complete for data index  442
# Complete for data index  443
# Complete for data index  444
# Complete for data index  445
# Complete for data index  446
# Complete for data index  447
# Complete for data index  448
# Complete for data index  449
# Complete for data index  450
# Complete for data index  451
# Complete for data index  452
# Complete for data index  453
# Complete for data index  454
# Complete for data index  455
# Complete for data index  456
# Complete for data index  457
# Complete for data index  458
# Complete for data index  459
# Complete for data index  460
# Complete for data index  461
# Complete for data index  462
# Complete for data index  463
# Complete for data index  464
# Complete for data index  465
# Complete for data index  466
# Complete for data index  467
# Complete for data index  468
# Complete for data index  469
# Complete for data index  470
# Complete for data index  471
# Complete for data index  472
# Complete for data index  473
# Complete for data index  474
# Complete for data index  475
# Complete for data index  476
# Complete for data index  477
# Complete for data index  478
# Complete for data index  479
# Complete for data index  480
# Complete for data index  481
# Complete for data index  482
# Complete for data index  483
# Complete for data index  484
# Complete for data index  485
# Complete for data index  486
# Complete for data index  487
# Complete for data index  488
# Complete for data index  489
# Complete for data index  490
# Complete for data index  491
# Complete for data index  492
# Complete for data index  493
# Complete for data index  494
# Complete for data index  495
# Complete for data index  496
# Complete for data index  497
# Complete for data index  498
# Complete for data index  499
# Complete for data index  500
# Complete for data index  501
# Complete for data index  502
# Complete for data index  503
# Complete for data index  504
# Complete for data index  505
# Complete for data index  506
# Complete for data index  507
# Complete for data index  508
# Complete for data index  509
# Complete for data index  510
# Complete for data index  511
# Complete for data index  512
# Complete for data index  513
# Complete for data index  514
# Complete for data index  515
# Complete for data index  516
# Complete for data index  517
# Complete for data index  518
# Complete for data index  519
# Complete for data index  520
# Complete for data index  521
# Complete for data index  522
# Complete for data index  523
# Complete for data index  524
# Complete for data index  525
# Complete for data index  526
# Complete for data index  527
# Complete for data index  528
# Complete for data index  529
# Complete for data index  530
# Complete for data index  531
# Complete for data index  532
# Complete for data index  533
# Complete for data index  534
# Complete for data index  535
# Complete for data index  536
# Complete for data index  537
# Complete for data index  538
# Complete for data index  539
# Complete for data index  540
# Complete for data index  541
# Complete for data index  542
# Complete for data index  543
# Complete for data index  544
# Complete for data index  545
# Complete for data index  546
# Complete for data index  547
# Complete for data index  548
# Complete for data index  549
# Complete for data index  550
# Complete for data index  551
# Complete for data index  552
# Complete for data index  553
# Complete for data index  554
# Complete for data index  555
# Complete for data index  556
# Complete for data index  557
# Complete for data index  558
# Complete for data index  559
# Complete for data index  560
# Complete for data index  561
# Complete for data index  562
# Complete for data index  563
# Complete for data index  564
# Complete for data index  565
# Complete for data index  566
# Complete for data index  567
# Complete for data index  568
# Complete for data index  569
# Complete for data index  570
# Complete for data index  571
# Complete for data index  572
# Complete for data index  573
# Complete for data index  574
# Complete for data index  575
# Complete for data index  576
# Complete for data index  577
# Complete for data index  578
# Complete for data index  579
# Complete for data index  580
# Complete for data index  581
# Complete for data index  582
# Complete for data index  583
# Complete for data index  584
# Complete for data index  585
# Complete for data index  586
# Complete for data index  587
# Complete for data index  588
# Complete for data index  589
# Complete for data index  590
# Complete for data index  591
# Complete for data index  592
# Complete for data index  593
# Complete for data index  594
# Complete for data index  595
# Complete for data index  596
# Complete for data index  597
# Complete for data index  598
# Complete for data index  599
# Complete for data index  600
# Complete for data index  601
# Complete for data index  602
# Complete for data index  603
# Complete for data index  604
# Complete for data index  605
# Complete for data index  606
# Complete for data index  607
# Complete for data index  608
# Complete for data index  609
# Complete for data index  610
# Complete for data index  611
# Complete for data index  612
# Complete for data index  613
# Complete for data index  614
# Complete for data index  615
# Complete for data index  616
# Complete for data index  617
# Complete for data index  618
# Complete for data index  619
# Complete for data index  620
# Complete for data index  621
# Complete for data index  622
# Complete for data index  623
# Complete for data index  624
# Complete for data index  625
# Complete for data index  626
# Complete for data index  627
# Complete for data index  628
# Complete for data index  629
# Complete for data index  630
# Complete for data index  631
# Complete for data index  632
# Complete for data index  633
# Complete for data index  634
# Complete for data index  635
# Complete for data index  636
# Complete for data index  637
# Complete for data index  638
# Complete for data index  639
# Complete for data index  640
# Complete for data index  641
# Complete for data index  642
# Complete for data index  643
# Complete for data index  644
# Complete for data index  645
# Complete for data index  646
# Complete for data index  647
# Complete for data index  648
# Complete for data index  649
# Complete for data index  650
# Complete for data index  651
# Complete for data index  652
# Complete for data index  653
# Complete for data index  654
# Complete for data index  655
# Complete for data index  656
# Complete for data index  657
# Complete for data index  658
# Complete for data index  659
# Complete for data index  660
# Complete for data index  661
# Complete for data index  662
# Complete for data index  663
# Complete for data index  664
# Complete for data index  665
# Complete for data index  666
# Complete for data index  667
# Complete for data index  668
# Complete for data index  669
# Complete for data index  670
# Complete for data index  671
# Complete for data index  672
# Complete for data index  673
# Complete for data index  674
# Complete for data index  675
# Complete for data index  676
# Complete for data index  677
# Complete for data index  678
# Complete for data index  679
# Complete for data index  680
# Complete for data index  681
# Complete for data index  682
# Complete for data index  683
# Complete for data index  684
# Complete for data index  685
# Complete for data index  686
# Complete for data index  687
# Complete for data index  688
# Complete for data index  689
# Complete for data index  690
# Complete for data index  691
# Complete for data index  692
# Complete for data index  693
# Complete for data index  694
# Complete for data index  695
# Complete for data index  696
# Complete for data index  697
# Complete for data index  698
# Complete for data index  699
# Complete for data index  700
# Complete for data index  701
# Complete for data index  702
# Complete for data index  703
# Complete for data index  704
# Complete for data index  705
# Complete for data index  706
# Complete for data index  707
# Complete for data index  708
# Complete for data index  709
# Complete for data index  710
# Complete for data index  711
# Complete for data index  712
# Complete for data index  713
# Complete for data index  714
# Complete for data index  715
# Complete for data index  716
# Complete for data index  717
# Complete for data index  718
# Complete for data index  719
# Complete for data index  720
# Complete for data index  721
# Complete for data index  722
# Complete for data index  723
# Complete for data index  724
# Complete for data index  725
# Complete for data index  726
# Complete for data index  727
# Complete for data index  728
# Complete for data index  729
# Complete for data index  730
# Complete for data index  731
# Complete for data index  732
# Complete for data index  733
# Complete for data index  734
# Complete for data index  735
# Complete for data index  736
# Complete for data index  737
# Complete for data index  738
# Complete for data index  739
# Complete for data index  740
# Complete for data index  741
# Complete for data index  742
# Complete for data index  743
# Complete for data index  744
# Complete for data index  745
# Complete for data index  746
# Complete for data index  747
# Complete for data index  748
# Complete for data index  749
# Complete for data index  750
# Complete for data index  751
# Complete for data index  752
# Complete for data index  753
# Complete for data index  754
# Complete for data index  755
# Complete for data index  756
# Complete for data index  757
# Complete for data index  758
# Complete for data index  759
# Complete for data index  760
# Complete for data index  761
# Complete for data index  762
# Complete for data index  763
# Complete for data index  764
# Complete for data index  765
# Complete for data index  766
# Complete for data index  767
# Complete for data index  768
# Complete for data index  769
# Complete for data index  770
# Complete for data index  771
# Complete for data index  772
# Complete for data index  773
# Complete for data index  774
# Complete for data index  775
# Complete for data index  776
# Complete for data index  777
# Complete for data index  778
# Complete for data index  779
# Complete for data index  780
# Complete for data index  781
# Complete for data index  782
# Complete for data index  783
# Complete for data index  784
# Complete for data index  785
# Complete for data index  786
# Complete for data index  787
# Complete for data index  788
# Complete for data index  789
# Complete for data index  790
# Complete for data index  791
# Complete for data index  792
# Complete for data index  793
# Complete for data index  794
# Complete for data index  795
# Complete for data index  796
# Complete for data index  797
# Complete for data index  798
# Complete for data index  799
# Complete for data index  800
# Complete for data index  801
# Complete for data index  802
# Complete for data index  803
# Complete for data index  804
# Complete for data index  805
# Complete for data index  806
# Complete for data index  807
# Complete for data index  808
# Complete for data index  809
# Complete for data index  810
# Complete for data index  811
# Complete for data index  812
# Complete for data index  813
# Complete for data index  814
# Complete for data index  815
# Complete for data index  816
# Complete for data index  817
# Complete for data index  818
# Complete for data index  819
# Complete for data index  820
# Complete for data index  821
# Complete for data index  822
# Complete for data index  823
# Complete for data index  824
# Complete for data index  825
# Complete for data index  826
# Complete for data index  827
# Complete for data index  828
# Complete for data index  829
# Complete for data index  830
# Complete for data index  831
# Complete for data index  832
# Complete for data index  833
# Complete for data index  834
# Complete for data index  835
# Complete for data index  836
# Complete for data index  837
# Complete for data index  838
# Complete for data index  839
# Complete for data index  840
# Complete for data index  841
# Complete for data index  842
# Complete for data index  843
# Complete for data index  844
# Complete for data index  845
# Complete for data index  846
# Complete for data index  847
# Complete for data index  848
# Complete for data index  849
# Complete for data index  850
# Complete for data index  851
# Complete for data index  852
# Complete for data index  853
# Complete for data index  854
# Complete for data index  855
# Complete for data index  856
# Complete for data index  857
# Complete for data index  858
# Complete for data index  859
# Complete for data index  860
# Complete for data index  861
# Complete for data index  862
# Complete for data index  863
# Complete for data index  864
# Complete for data index  865
# Complete for data index  866
# Complete for data index  867
# Complete for data index  868
# Complete for data index  869
# Complete for data index  870
# Complete for data index  871
# Complete for data index  872
# Complete for data index  873
# Complete for data index  874
# Complete for data index  875
# Complete for data index  876
# Complete for data index  877
# Complete for data index  878
# Complete for data index  879
# Complete for data index  880
# Complete for data index  881
# Complete for data index  882
# Complete for data index  883
# Complete for data index  884
# Complete for data index  885
# Complete for data index  886
# Complete for data index  887
# Complete for data index  888
# Complete for data index  889
# Complete for data index  890
# Complete for data index  891
# Complete for data index  892
# Complete for data index  893
# Complete for data index  894
# Complete for data index  895
# Complete for data index  896
# Complete for data index  897
# Complete for data index  898
# Complete for data index  899
# Complete for data index  900
# Complete for data index  901
# Complete for data index  902
# Complete for data index  903
# Complete for data index  904
# Complete for data index  905
# Complete for data index  906
# Complete for data index  907
# Complete for data index  908
# Complete for data index  909
# Complete for data index  910
# Complete for data index  911
# Complete for data index  912
# Complete for data index  913
# Complete for data index  914
# Complete for data index  915
# Complete for data index  916
# Complete for data index  917
# Complete for data index  918
# Complete for data index  919
# Complete for data index  920
# Complete for data index  921
# Complete for data index  922
# Complete for data index  923
# Complete for data index  924
# Complete for data index  925
# Complete for data index  926
# Complete for data index  927
# Complete for data index  928
# Complete for data index  929
# Complete for data index  930
# Complete for data index  931
# Complete for data index  932
# Complete for data index  933
# Complete for data index  934
# Complete for data index  935
# Complete for data index  936
# Complete for data index  937
# Complete for data index  938
# Complete for data index  939
# Complete for data index  940
# Complete for data index  941
# Complete for data index  942
# Complete for data index  943
# Complete for data index  944
# Complete for data index  945
# Complete for data index  946
# Complete for data index  947
# Complete for data index  948
# Complete for data index  949
# Complete for data index  950
# Complete for data index  951
# Complete for data index  952
# Complete for data index  953
# Complete for data index  954
# Complete for data index  955
# Complete for data index  956
# Complete for data index  957
# Complete for data index  958
# Complete for data index  959
# Complete for data index  960
# Complete for data index  961
# Complete for data index  962
# Complete for data index  963
# Complete for data index  964
# Complete for data index  965
# Complete for data index  966
# Complete for data index  967
# Complete for data index  968
# Complete for data index  969
# Complete for data index  970
# Complete for data index  971
# Complete for data index  972
# Complete for data index  973
# Complete for data index  974
# Complete for data index  975
# Complete for data index  976
# Complete for data index  977
# Complete for data index  978
# Complete for data index  979
# Complete for data index  980
# Complete for data index  981
# Complete for data index  982
# Complete for data index  983
# Complete for data index  984
# Complete for data index  985
# Complete for data index  986
# Complete for data index  987
# Complete for data index  988
# Complete for data index  989
# Complete for data index  990
# Complete for data index  991
# Complete for data index  992
# Complete for data index  993
# Complete for data index  994
# Complete for data index  995
# Complete for data index  996
# Complete for data index  997
# Complete for data index  998
# Complete for data index  999
# Complete for data index  1000
# Complete for data index  1001
# Complete for data index  1002
# Complete for data index  1003
# Complete for data index  1004
# Complete for data index  1005
# Complete for data index  1006
# Complete for data index  1007
# Complete for data index  1008
# Complete for data index  1009
# Complete for data index  1010
# Complete for data index  1011
# Complete for data index  1012
# Complete for data index  1013
# Complete for data index  1014
# Complete for data index  1015
# Complete for data index  1016
# Complete for data index  1017
# Complete for data index  1018
# Complete for data index  1019
# Complete for data index  1020
# Complete for data index  1021
# Complete for data index  1022
# Complete for data index  1023
# Complete for data index  1024
# Complete for data index  1025
# Complete for data index  1026
# Complete for data index  1027
# Complete for data index  1028
# Complete for data index  1029
# Complete for data index  1030
# Complete for data index  1031
# Complete for data index  1032
# Complete for data index  1033
# Complete for data index  1034
# Complete for data index  1035
# Complete for data index  1036
# Complete for data index  1037
# Complete for data index  1038
# Complete for data index  1039
# Complete for data index  1040
# Complete for data index  1041
# Complete for data index  1042
# Complete for data index  1043
# Complete for data index  1044
# Complete for data index  1045
# Complete for data index  1046
# Complete for data index  1047
# Complete for data index  1048
# Complete for data index  1049
# Complete for data index  1050
# Complete for data index  1051
# Complete for data index  1052
# Complete for data index  1053
# Complete for data index  1054
# Complete for data index  1055
# Complete for data index  1056
# Complete for data index  1057
# Complete for data index  1058
# Complete for data index  1059
# Complete for data index  1060
# Complete for data index  1061
# Complete for data index  1062
# Complete for data index  1063
# Complete for data index  1064
# Complete for data index  1065
# Complete for data index  1066
# Complete for data index  1067
# Complete for data index  1068
# Complete for data index  1069
# Complete for data index  1070
# Complete for data index  1071
# Complete for data index  1072
# Complete for data index  1073
# Complete for data index  1074
# Complete for data index  1075
# Complete for data index  1076
# Complete for data index  1077
# Complete for data index  1078
# Complete for data index  1079
# Complete for data index  1080
# Complete for data index  1081
# Complete for data index  1082
# Complete for data index  1083
# Complete for data index  1084
# Complete for data index  1085
# Complete for data index  1086
# Complete for data index  1087
# Complete for data index  1088
# Complete for data index  1089
# Complete for data index  1090
# Complete for data index  1091
# Complete for data index  1092
# Complete for data index  1093
# Complete for data index  1094
# Complete for data index  1095
# Complete for data index  1096
# Complete for data index  1097
# Complete for data index  1098
# Complete for data index  1099
# Complete for data index  1100
# Complete for data index  1101
# Complete for data index  1102
# Complete for data index  1103
# Complete for data index  1104
# Complete for data index  1105
# Complete for data index  1106
# Complete for data index  1107
# Complete for data index  1108
# Complete for data index  1109
# Complete for data index  1110
# Complete for data index  1111
# Complete for data index  1112
# Complete for data index  1113
# Complete for data index  1114
# Complete for data index  1115
# Complete for data index  1116
# Complete for data index  1117
# Complete for data index  1118
# Complete for data index  1119
# Complete for data index  1120
# Complete for data index  1121
# Complete for data index  1122
# Complete for data index  1123
# Complete for data index  1124
# Complete for data index  1125
# Complete for data index  1126
# Complete for data index  1127
# Complete for data index  1128
# Complete for data index  1129
# Complete for data index  1130
# Complete for data index  1131
# Complete for data index  1132
# Complete for data index  1133
# Complete for data index  1134
# Complete for data index  1135
# Complete for data index  1136
# Complete for data index  1137
# Complete for data index  1138
# Complete for data index  1139
# Complete for data index  1140
# Complete for data index  1141
# Complete for data index  1142
# Complete for data index  1143
# Complete for data index  1144
# Complete for data index  1145
# Complete for data index  1146
# Complete for data index  1147
# Complete for data index  1148
# Complete for data index  1149
# Complete for data index  1150
# Complete for data index  1151
# Complete for data index  1152
# Complete for data index  1153
# Complete for data index  1154
# Complete for data index  1155
# Complete for data index  1156
# Complete for data index  1157
# Complete for data index  1158
# Complete for data index  1159
# Complete for data index  1160
# Complete for data index  1161
# Complete for data index  1162
# Complete for data index  1163
# Complete for data index  1164
# Complete for data index  1165
# Complete for data index  1166
# Complete for data index  1167
# Complete for data index  1168
# Complete for data index  1169
# Complete for data index  1170
# Complete for data index  1171
# Complete for data index  1172
# Complete for data index  1173
# Complete for data index  1174
# Complete for data index  1175
# Complete for data index  1176
# Complete for data index  1177
# Complete for data index  1178
# Complete for data index  1179
# Complete for data index  1180
# Complete for data index  1181
# Complete for data index  1182
# Complete for data index  1183
# Complete for data index  1184
# Complete for data index  1185
# Complete for data index  1186
# Complete for data index  1187
# Complete for data index  1188
# Complete for data index  1189
# Complete for data index  1190
# Complete for data index  1191
# Complete for data index  1192
# Complete for data index  1193
# Complete for data index  1194
# Complete for data index  1195
# Complete for data index  1196
# Complete for data index  1197
# Complete for data index  1198
# Complete for data index  1199
# Complete for data index  1200
# Complete for data index  1201
# Complete for data index  1202
# Complete for data index  1203
# Complete for data index  1204
# Complete for data index  1205
# Complete for data index  1206
# Complete for data index  1207
# Complete for data index  1208
# Complete for data index  1209
# Complete for data index  1210
# Complete for data index  1211
# Complete for data index  1212
# Complete for data index  1213
# Complete for data index  1214
# Complete for data index  1215
# Complete for data index  1216
# Complete for data index  1217
# Complete for data index  1218
# Complete for data index  1219
# Complete for data index  1220
# Complete for data index  1221
# Complete for data index  1222
# Complete for data index  1223
# Complete for data index  1224
# Complete for data index  1225
# Complete for data index  1226
# Complete for data index  1227
# Complete for data index  1228
# Complete for data index  1229
# Complete for data index  1230
# Complete for data index  1231
# Complete for data index  1232
# Complete for data index  1233
# Complete for data index  1234
# Complete for data index  1235
# Complete for data index  1236
# Complete for data index  1237
# Complete for data index  1238
# Complete for data index  1239
# Complete for data index  1240
# Complete for data index  1241
# Complete for data index  1242
# Complete for data index  1243
# Complete for data index  1244
# Complete for data index  1245
# Complete for data index  1246
# Complete for data index  1247
# Complete for data index  1248
# Complete for data index  1249
# Complete for data index  1250
# Complete for data index  1251
# Complete for data index  1252
# Complete for data index  1253
# Complete for data index  1254
# Complete for data index  1255
# Complete for data index  1256
# Complete for data index  1257
# Complete for data index  1258
# Complete for data index  1259
# Complete for data index  1260
# Complete for data index  1261
# Complete for data index  1262
# Complete for data index  1263
# Complete for data index  1264
# Complete for data index  1265
# Complete for data index  1266
# Complete for data index  1267
# Complete for data index  1268
# Complete for data index  1269
# Complete for data index  1270
# Complete for data index  1271
# Complete for data index  1272
# Complete for data index  1273
# Complete for data index  1274
# Complete for data index  1275
# Complete for data index  1276
# Complete for data index  1277
# Complete for data index  1278
# Complete for data index  1279
# Complete for data index  1280
# Complete for data index  1281
# Complete for data index  1282
# Complete for data index  1283
# Complete for data index  1284
# Complete for data index  1285
# Complete for data index  1286
# Complete for data index  1287
# Complete for data index  1288
# Complete for data index  1289
# Complete for data index  1290
# Complete for data index  1291
# Complete for data index  1292
# Complete for data index  1293
# Complete for data index  1294
# Complete for data index  1295
# Complete for data index  1296
# Complete for data index  1297
# Complete for data index  1298
# Complete for data index  1299
# Complete for data index  1300
# Complete for data index  1301
# Complete for data index  1302
# Complete for data index  1303
# Complete for data index  1304
# Complete for data index  1305
# Complete for data index  1306
# Complete for data index  1307
# Complete for data index  1308
# Complete for data index  1309
# Complete for data index  1310
# Complete for data index  1311
# Complete for data index  1312
# Complete for data index  1313
# Complete for data index  1314
# Complete for data index  1315
# Complete for data index  1316
# Complete for data index  1317
# Complete for data index  1318
# Complete for data index  1319
# Complete for data index  1320
# Complete for data index  1321
# Complete for data index  1322
# Complete for data index  1323
# Complete for data index  1324
# Complete for data index  1325
# Complete for data index  1326
# Complete for data index  1327
# Complete for data index  1328
# Complete for data index  1329
# Complete for data index  1330
# Complete for data index  1331
# Complete for data index  1332
# Complete for data index  1333
# Complete for data index  1334
# Complete for data index  1335
# Complete for data index  1336
# Complete for data index  1337
# Complete for data index  1338
# Complete for data index  1339
# Complete for data index  1340
# Complete for data index  1341
# Complete for data index  1342
# Complete for data index  1343
# Complete for data index  1344
# Complete for data index  1345
# Complete for data index  1346
# Complete for data index  1347
# Complete for data index  1348
# Complete for data index  1349
# Complete for data index  1350
# Complete for data index  1351
# Complete for data index  1352
# Complete for data index  1353
# Complete for data index  1354
# Complete for data index  1355
# Complete for data index  1356
# Complete for data index  1357
# Complete for data index  1358
# Complete for data index  1359
# Complete for data index  1360
# Complete for data index  1361
# Complete for data index  1362
# Complete for data index  1363
# Complete for data index  1364
# Complete for data index  1365
# Complete for data index  1366
# Complete for data index  1367
# Complete for data index  1368
# Complete for data index  1369
# Complete for data index  1370
# Complete for data index  1371
# Complete for data index  1372
# Complete for data index  1373
# Complete for data index  1374
# Complete for data index  1375
# Complete for data index  1376
# Complete for data index  1377
# Complete for data index  1378
# Complete for data index  1379
# Complete for data index  1380
# Complete for data index  1381
# Complete for data index  1382
# Complete for data index  1383
# Complete for data index  1384
# Complete for data index  1385
# Complete for data index  1386
# Complete for data index  1387
# Complete for data index  1388
# Complete for data index  1389
# Complete for data index  1390
# Complete for data index  1391
# Complete for data index  1392
# Complete for data index  1393
# Complete for data index  1394
# Complete for data index  1395
# Complete for data index  1396
# Complete for data index  1397
# Complete for data index  1398
# Complete for data index  1399
# Complete for data index  1400
# Complete for data index  1401
# Complete for data index  1402
# Complete for data index  1403
# Complete for data index  1404
# Complete for data index  1405
# Complete for data index  1406
# Complete for data index  1407
# Complete for data index  1408
# Complete for data index  1409
# Complete for data index  1410
# Complete for data index  1411
# Complete for data index  1412
# Complete for data index  1413
# Complete for data index  1414
# Complete for data index  1415
# Complete for data index  1416
# Complete for data index  1417
# Complete for data index  1418
# Complete for data index  1419
# Complete for data index  1420
# Complete for data index  1421
# Complete for data index  1422
# Complete for data index  1423
# Complete for data index  1424
# Complete for data index  1425
# Complete for data index  1426
# Complete for data index  1427
# Complete for data index  1428
# Complete for data index  1429
# Complete for data index  1430
# Complete for data index  1431
# Complete for data index  1432
# Complete for data index  1433
# Complete for data index  1434
# Complete for data index  1435
# Complete for data index  1436
# Complete for data index  1437
# Complete for data index  1438
# Complete for data index  1439
# Complete for data index  1440
# Complete for data index  1441
# Complete for data index  1442
# Complete for data index  1443
# Complete for data index  1444
# Complete for data index  1445
# Complete for data index  1446
# Complete for data index  1447
# Complete for data index  1448
# Complete for data index  1449
# Complete for data index  1450
# Complete for data index  1451
# Complete for data index  1452
# Complete for data index  1453
# Complete for data index  1454
# Complete for data index  1455
# Complete for data index  1456
# Complete for data index  1457
# Complete for data index  1458
# Complete for data index  1459
# Complete for data index  1460
# Complete for data index  1461
# Complete for data index  1462
# Complete for data index  1463
# Complete for data index  1464
# Complete for data index  1465
# Complete for data index  1466
# Complete for data index  1467
# Complete for data index  1468
# Complete for data index  1469
# Complete for data index  1470
# Complete for data index  1471
# Complete for data index  1472
# Complete for data index  1473
# Complete for data index  1474
# Complete for data index  1475
# Complete for data index  1476
# Complete for data index  1477
# Complete for data index  1478
# Complete for data index  1479
# Complete for data index  1480
# Complete for data index  1481
# Complete for data index  1482
# Complete for data index  1483
# Complete for data index  1484
# Complete for data index  1485
# Complete for data index  1486
# Complete for data index  1487
# Complete for data index  1488
# Complete for data index  1489
# Complete for data index  1490
# Complete for data index  1491
# Complete for data index  1492
# Complete for data index  1493
# Complete for data index  1494
# Complete for data index  1495
# Complete for data index  1496
# Complete for data index  1497
# Complete for data index  1498
# Complete for data index  1499
# Complete for data index  1500
# Complete for data index  1501
# Complete for data index  1502
# Complete for data index  1503
# Complete for data index  1504
# Complete for data index  1505
# Complete for data index  1506
# Complete for data index  1507
# Complete for data index  1508
# Complete for data index  1509
# Complete for data index  1510
# Complete for data index  1511
# Complete for data index  1512
# Complete for data index  1513
# Complete for data index  1514
# Complete for data index  1515
# Complete for data index  1516
# Complete for data index  1517
# Complete for data index  1518
# Complete for data index  1519
# Complete for data index  1520
# Complete for data index  1521
# Complete for data index  1522
# Complete for data index  1523
# Complete for data index  1524
# Complete for data index  1525
# Complete for data index  1526
# Complete for data index  1527
# Complete for data index  1528
# Complete for data index  1529
# Complete for data index  1530
# Complete for data index  1531
# Complete for data index  1532
# Complete for data index  1533
# Complete for data index  1534
# Complete for data index  1535
# Complete for data index  1536
# Complete for data index  1537
# Complete for data index  1538
# Complete for data index  1539
# Complete for data index  1540
# Complete for data index  1541
# Complete for data index  1542
# Complete for data index  1543
# Complete for data index  1544
# Complete for data index  1545
# Complete for data index  1546
# Complete for data index  1547
# Complete for data index  1548
# Complete for data index  1549
# Complete for data index  1550
# Complete for data index  1551
# Complete for data index  1552
# Complete for data index  1553
# Complete for data index  1554
# Complete for data index  1555
# Complete for data index  1556
# Complete for data index  1557
# Complete for data index  1558
# Complete for data index  1559
# Complete for data index  1560
# Complete for data index  1561
# Complete for data index  1562
# Complete for data index  1563
# Complete for data index  1564
# Complete for data index  1565
# Complete for data index  1566
# Complete for data index  1567
# Complete for data index  1568
# Complete for data index  1569
# Complete for data index  1570
# Complete for data index  1571
# Complete for data index  1572
# Complete for data index  1573
# Complete for data index  1574
# Complete for data index  1575
# Complete for data index  1576
# Complete for data index  1577
# Complete for data index  1578
# Complete for data index  1579
# Complete for data index  1580
# Complete for data index  1581
# Complete for data index  1582
# Complete for data index  1583
# Complete for data index  1584
# Complete for data index  1585
# Complete for data index  1586
# Complete for data index  1587
# Complete for data index  1588
# Complete for data index  1589
# Complete for data index  1590
# Complete for data index  1591
# Complete for data index  1592
# Complete for data index  1593
# Complete for data index  1594
# Complete for data index  1595
# Complete for data index  1596
# Complete for data index  1597
# Complete for data index  1598
# Complete for data index  1599
# Complete for data index  1600
# Complete for data index  1601
# Complete for data index  1602
# Complete for data index  1603
# Complete for data index  1604
# Complete for data index  1605
# Complete for data index  1606
# Complete for data index  1607
# Complete for data index  1608
# Complete for data index  1609
# Complete for data index  1610
# Complete for data index  1611
# Complete for data index  1612
# Complete for data index  1613
# Complete for data index  1614
# Complete for data index  1615
# Complete for data index  1616
# Complete for data index  1617
# Complete for data index  1618
# Complete for data index  1619
# Complete for data index  1620
# Complete for data index  1621
# Complete for data index  1622
# Complete for data index  1623
# Complete for data index  1624
# Complete for data index  1625
# Complete for data index  1626
# Complete for data index  1627
# Complete for data index  1628
# Complete for data index  1629
# Complete for data index  1630
# Preprocess complete.
# Training start...
# Epoch 1/50
# 41/41 [==============================] - 5s 41ms/step - loss: 0.9160 - conv2d_67_loss: 0.7350 - conv2d_68_loss: 0.1810 - conv2d_67_accuracy: 0.5231 - conv2d_68_accuracy: 0.5291
# Epoch 2/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.6372 - conv2d_67_loss: 0.5508 - conv2d_68_loss: 0.0864 - conv2d_67_accuracy: 0.7695 - conv2d_68_accuracy: 0.8236
# Epoch 3/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.5299 - conv2d_67_loss: 0.4677 - conv2d_68_loss: 0.0622 - conv2d_67_accuracy: 0.8378 - conv2d_68_accuracy: 0.8737
# Epoch 4/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.4552 - conv2d_67_loss: 0.4028 - conv2d_68_loss: 0.0524 - conv2d_67_accuracy: 0.8595 - conv2d_68_accuracy: 0.8827
# Epoch 5/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.3981 - conv2d_67_loss: 0.3515 - conv2d_68_loss: 0.0466 - conv2d_67_accuracy: 0.8738 - conv2d_68_accuracy: 0.8882
# Epoch 6/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.3574 - conv2d_67_loss: 0.3154 - conv2d_68_loss: 0.0420 - conv2d_67_accuracy: 0.8839 - conv2d_68_accuracy: 0.8957
# Epoch 7/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.3264 - conv2d_67_loss: 0.2897 - conv2d_68_loss: 0.0367 - conv2d_67_accuracy: 0.8906 - conv2d_68_accuracy: 0.9135
# Epoch 8/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.2963 - conv2d_67_loss: 0.2649 - conv2d_68_loss: 0.0314 - conv2d_67_accuracy: 0.8988 - conv2d_68_accuracy: 0.9329
# Epoch 9/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.2780 - conv2d_67_loss: 0.2496 - conv2d_68_loss: 0.0284 - conv2d_67_accuracy: 0.9036 - conv2d_68_accuracy: 0.9434
# Epoch 10/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.2564 - conv2d_67_loss: 0.2303 - conv2d_68_loss: 0.0261 - conv2d_67_accuracy: 0.9111 - conv2d_68_accuracy: 0.9493
# Epoch 11/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.2410 - conv2d_67_loss: 0.2167 - conv2d_68_loss: 0.0244 - conv2d_67_accuracy: 0.9155 - conv2d_68_accuracy: 0.9524
# Epoch 12/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.2269 - conv2d_67_loss: 0.2040 - conv2d_68_loss: 0.0229 - conv2d_67_accuracy: 0.9204 - conv2d_68_accuracy: 0.9544
# Epoch 13/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.2207 - conv2d_67_loss: 0.1990 - conv2d_68_loss: 0.0216 - conv2d_67_accuracy: 0.9213 - conv2d_68_accuracy: 0.9555
# Epoch 14/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.2051 - conv2d_67_loss: 0.1848 - conv2d_68_loss: 0.0203 - conv2d_67_accuracy: 0.9276 - conv2d_68_accuracy: 0.9564
# Epoch 15/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.1984 - conv2d_67_loss: 0.1791 - conv2d_68_loss: 0.0193 - conv2d_67_accuracy: 0.9287 - conv2d_68_accuracy: 0.9567
# Epoch 16/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1919 - conv2d_67_loss: 0.1736 - conv2d_68_loss: 0.0183 - conv2d_67_accuracy: 0.9306 - conv2d_68_accuracy: 0.9571
# Epoch 17/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1857 - conv2d_67_loss: 0.1683 - conv2d_68_loss: 0.0174 - conv2d_67_accuracy: 0.9320 - conv2d_68_accuracy: 0.9574
# Epoch 18/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1728 - conv2d_67_loss: 0.1562 - conv2d_68_loss: 0.0166 - conv2d_67_accuracy: 0.9375 - conv2d_68_accuracy: 0.9574
# Epoch 19/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1663 - conv2d_67_loss: 0.1505 - conv2d_68_loss: 0.0158 - conv2d_67_accuracy: 0.9396 - conv2d_68_accuracy: 0.9578
# Epoch 20/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1647 - conv2d_67_loss: 0.1495 - conv2d_68_loss: 0.0152 - conv2d_67_accuracy: 0.9394 - conv2d_68_accuracy: 0.9606
# Epoch 21/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.1595 - conv2d_67_loss: 0.1449 - conv2d_68_loss: 0.0146 - conv2d_67_accuracy: 0.9411 - conv2d_68_accuracy: 0.9615
# Epoch 22/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1583 - conv2d_67_loss: 0.1441 - conv2d_68_loss: 0.0142 - conv2d_67_accuracy: 0.9413 - conv2d_68_accuracy: 0.9631
# Epoch 23/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1504 - conv2d_67_loss: 0.1368 - conv2d_68_loss: 0.0136 - conv2d_67_accuracy: 0.9442 - conv2d_68_accuracy: 0.9664
# Epoch 24/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1482 - conv2d_67_loss: 0.1350 - conv2d_68_loss: 0.0132 - conv2d_67_accuracy: 0.9447 - conv2d_68_accuracy: 0.9686
# Epoch 25/50
# 41/41 [==============================] - 2s 41ms/step - loss: 0.1453 - conv2d_67_loss: 0.1325 - conv2d_68_loss: 0.0128 - conv2d_67_accuracy: 0.9455 - conv2d_68_accuracy: 0.9699
# Epoch 26/50
# 41/41 [==============================] - 2s 45ms/step - loss: 0.1416 - conv2d_67_loss: 0.1291 - conv2d_68_loss: 0.0124 - conv2d_67_accuracy: 0.9464 - conv2d_68_accuracy: 0.9709
# Epoch 27/50
# 41/41 [==============================] - 2s 42ms/step - loss: 0.1366 - conv2d_67_loss: 0.1245 - conv2d_68_loss: 0.0121 - conv2d_67_accuracy: 0.9486 - conv2d_68_accuracy: 0.9714
# Epoch 28/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.1347 - conv2d_67_loss: 0.1229 - conv2d_68_loss: 0.0118 - conv2d_67_accuracy: 0.9490 - conv2d_68_accuracy: 0.9717
# Epoch 29/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1365 - conv2d_67_loss: 0.1249 - conv2d_68_loss: 0.0116 - conv2d_67_accuracy: 0.9482 - conv2d_68_accuracy: 0.9718
# Epoch 30/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1337 - conv2d_67_loss: 0.1224 - conv2d_68_loss: 0.0113 - conv2d_67_accuracy: 0.9489 - conv2d_68_accuracy: 0.9720
# Epoch 31/50
# 41/41 [==============================] - 2s 38ms/step - loss: 0.1314 - conv2d_67_loss: 0.1203 - conv2d_68_loss: 0.0110 - conv2d_67_accuracy: 0.9497 - conv2d_68_accuracy: 0.9721
# Epoch 32/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1285 - conv2d_67_loss: 0.1177 - conv2d_68_loss: 0.0108 - conv2d_67_accuracy: 0.9506 - conv2d_68_accuracy: 0.9722
# Epoch 33/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1299 - conv2d_67_loss: 0.1191 - conv2d_68_loss: 0.0107 - conv2d_67_accuracy: 0.9498 - conv2d_68_accuracy: 0.9723
# Epoch 34/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1244 - conv2d_67_loss: 0.1139 - conv2d_68_loss: 0.0105 - conv2d_67_accuracy: 0.9518 - conv2d_68_accuracy: 0.9724
# Epoch 35/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1270 - conv2d_67_loss: 0.1166 - conv2d_68_loss: 0.0103 - conv2d_67_accuracy: 0.9509 - conv2d_68_accuracy: 0.9725
# Epoch 36/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1226 - conv2d_67_loss: 0.1125 - conv2d_68_loss: 0.0102 - conv2d_67_accuracy: 0.9525 - conv2d_68_accuracy: 0.9765
# Epoch 37/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1198 - conv2d_67_loss: 0.1098 - conv2d_68_loss: 0.0100 - conv2d_67_accuracy: 0.9534 - conv2d_68_accuracy: 0.9811
# Epoch 38/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1155 - conv2d_67_loss: 0.1058 - conv2d_68_loss: 0.0097 - conv2d_67_accuracy: 0.9549 - conv2d_68_accuracy: 0.9812
# Epoch 39/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1169 - conv2d_67_loss: 0.1072 - conv2d_68_loss: 0.0097 - conv2d_67_accuracy: 0.9543 - conv2d_68_accuracy: 0.9812
# Epoch 40/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1102 - conv2d_67_loss: 0.1008 - conv2d_68_loss: 0.0094 - conv2d_67_accuracy: 0.9570 - conv2d_68_accuracy: 0.9812
# Epoch 41/50
# 41/41 [==============================] - 2s 53ms/step - loss: 0.1110 - conv2d_67_loss: 0.1017 - conv2d_68_loss: 0.0093 - conv2d_67_accuracy: 0.9564 - conv2d_68_accuracy: 0.9812
# Epoch 42/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1068 - conv2d_67_loss: 0.0977 - conv2d_68_loss: 0.0091 - conv2d_67_accuracy: 0.9578 - conv2d_68_accuracy: 0.9812
# Epoch 43/50
# 41/41 [==============================] - 2s 38ms/step - loss: 0.1049 - conv2d_67_loss: 0.0959 - conv2d_68_loss: 0.0090 - conv2d_67_accuracy: 0.9586 - conv2d_68_accuracy: 0.9812
# Epoch 44/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1091 - conv2d_67_loss: 0.1001 - conv2d_68_loss: 0.0090 - conv2d_67_accuracy: 0.9573 - conv2d_68_accuracy: 0.9812
# Epoch 45/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1106 - conv2d_67_loss: 0.1016 - conv2d_68_loss: 0.0090 - conv2d_67_accuracy: 0.9565 - conv2d_68_accuracy: 0.9812
# Epoch 46/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1049 - conv2d_67_loss: 0.0961 - conv2d_68_loss: 0.0088 - conv2d_67_accuracy: 0.9584 - conv2d_68_accuracy: 0.9812
# Epoch 47/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1065 - conv2d_67_loss: 0.0978 - conv2d_68_loss: 0.0087 - conv2d_67_accuracy: 0.9580 - conv2d_68_accuracy: 0.9812
# Epoch 48/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1030 - conv2d_67_loss: 0.0944 - conv2d_68_loss: 0.0086 - conv2d_67_accuracy: 0.9593 - conv2d_68_accuracy: 0.9812
# Epoch 49/50
# 41/41 [==============================] - 2s 40ms/step - loss: 0.1008 - conv2d_67_loss: 0.0923 - conv2d_68_loss: 0.0085 - conv2d_67_accuracy: 0.9599 - conv2d_68_accuracy: 0.9812
# Epoch 50/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.1017 - conv2d_67_loss: 0.0932 - conv2d_68_loss: 0.0085 - conv2d_67_accuracy: 0.9597 - conv2d_68_accuracy: 0.9812
